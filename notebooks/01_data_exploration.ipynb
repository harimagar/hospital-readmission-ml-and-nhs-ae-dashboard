# %%
import os
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
import pandas as pd

df = pd.read_csv(r"D:\NHS-ML-Project\hospital-readmission-ml-and-nhs-ae-dashboard\data\nhs.csv", skiprows=14)
df.head()
# Out:
#   Unnamed: 0                                         Unnamed: 1  \
# 0       Code                                             System
# 1          -                                                  -
# 2        NaN                                                NaN
# 3        QOX  NHS Bath And North East Somerset, Swindon And ...
# 4        QHG  NHS Bedfordshire, Luton And Milton Keynes Inte...
#
#                   A&E attendances                             Unnamed: 3  \
# 0  Type 1 Departments - Major A&E  Type 2 Departments - Single Specialty
# 1                       1,478,144                                 55,393
# 2                             NaN                                    NaN
# 3                          20,771                                    377
# 4                          26,816                                      0
#
#                                          Unnamed: 4         Unnamed: 5  \
# ...

# %%
#check structure of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377 entries, 0 to 376
# Data columns (total 29 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   Unnamed: 0                                                                  44 non-null     object
#  1   Unnamed: 1                                                                  44 non-null     object
#  2   A&E attendances                                                             44 non-null     object
#  3   Unnamed: 3                                                                  44 non-null     object
#  4   Unnamed: 4                                                                  44 non-null     object
#  5   Unnamed: 5                                                                  44 non-null     object
# ...

# %%
#check missing values
df.isnull().sum()
# Out:
# Unnamed: 0                                                                    333
# Unnamed: 1                                                                    333
# A&E attendances                                                               333
# Unnamed: 3                                                                    333
# Unnamed: 4                                                                    333
# Unnamed: 5                                                                    333
# A&E attendances < 4 hours from arrival to admission, transfer or discharge    333
# Unnamed: 7                                                                    333
# Unnamed: 8                                                                    333
# Unnamed: 9                                                                    333
# A&E attendances > 4 hours from arrival to admission, transfer or discharge    333
# ...

# %%
#view basic statistics of the data
df.describe()
# Out:
#        Unnamed: 26  Unnamed: 27  Unnamed: 28
# count          0.0          0.0          0.0
# mean           NaN          NaN          NaN
# std            NaN          NaN          NaN
# min            NaN          NaN          NaN
# 25%            NaN          NaN          NaN
# 50%            NaN          NaN          NaN
# 75%            NaN          NaN          NaN
# max            NaN          NaN          NaN

# %%
df.tail()
# Out:
#     Unnamed: 0 Unnamed: 1 A&E attendances Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 372        NaN        NaN             NaN        NaN        NaN        NaN
# 373        NaN        NaN             NaN        NaN        NaN        NaN
# 374        NaN        NaN             NaN        NaN        NaN        NaN
# 375        NaN        NaN             NaN        NaN        NaN        NaN
# 376        NaN        NaN             NaN        NaN        NaN        NaN
#
#     A&E attendances < 4 hours from arrival to admission, transfer or discharge  \
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
# 375                                                NaN
# 376                                                NaN
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'A&E attendances', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5',
#        'A&E attendances < 4 hours from arrival to admission, transfer or discharge',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'A&E attendances > 4 hours from arrival to admission, transfer or discharge',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Percentage of attendances within 4 hours', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Emergency Admissions', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28'],
#       dtype='object')

# %%
df.head(10)
# Out:
#   Unnamed: 0                                         Unnamed: 1  \
# 0       Code                                             System
# 1          -                                                  -
# 2        NaN                                                NaN
# 3        QOX  NHS Bath And North East Somerset, Swindon And ...
# 4        QHG  NHS Bedfordshire, Luton And Milton Keynes Inte...
# 5        QHL  NHS Birmingham And Solihull Integrated Care Board
# 6        QUY  NHS Bristol, North Somerset And South Gloucest...
# 7        QU9  NHS Buckinghamshire, Oxfordshire And Berkshire...
# 8        QUE  NHS Cambridgeshire And Peterborough Integrated...
# 9        QYG  NHS Cheshire And Merseyside Integrated Care Board
#
#                   A&E attendances                             Unnamed: 3  \
# 0  Type 1 Departments - Major A&E  Type 2 Departments - Single Specialty
# 1                       1,478,144                                 55,393
# ...
